# %% [markdown]
# Impossible Climate Values

# %%
climate[climate["prcp"] < 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2901/2353596079.py in <cell line: 0>()
# ----> 1 climate[climate["prcp"] < 0]
#
# NameError: name 'climate' is not defined

# %%
climate[climate["tavg"] > 60]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2901/2927006561.py in <cell line: 0>()
# ----> 1 climate[climate["tavg"] > 60]
#
# NameError: name 'climate' is not defined

# %%
climate[climate["tavg"] < 0]
